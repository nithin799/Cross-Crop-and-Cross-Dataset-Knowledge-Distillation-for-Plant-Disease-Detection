# %% [markdown]
# # DenseNet121 KD Quantization: Direct Quantization of Saved Student Model
#
# This notebook loads the saved Densenet121 student trained via knowledge distillation and applies post-training quantization without retraining. We compare:
# - FP32 KD student baseline
# - TFLite quantized model
#
# Metrics: accuracy, model size, inference latency.

# %% [markdown]
# ## Step 1: Setup & Imports

# %%
import os
import time
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

print(f"TensorFlow version: {tf.__version__}")

current_dir = os.getcwd()
project_root = current_dir
while not (os.path.exists(os.path.join(project_root, 'Beans dataset')) and 
           os.path.exists(os.path.join(project_root, 'models'))):
    project_root = os.path.dirname(project_root)
    if project_root == os.path.dirname(project_root):
        raise RuntimeError("Could not find project root")

print(f"Project root: {project_root}")

DATA_DIR = os.path.join(project_root, "Beans dataset")
SAVE_DIR = os.path.join(project_root, "models")
RESULTS_DIR = os.path.join(project_root, "results", "quantization")
os.makedirs(RESULTS_DIR, exist_ok=True)

IMG_SIZE = (224, 224)
BATCH_SIZE = 8
SEED = 42
NUM_CLASSES = 3

train_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    labels="inferred",
    label_mode="int",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=SEED,
    validation_split=0.3,
    subset="training"
)
class_names = train_ds.class_names

val_test_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    labels="inferred",
    label_mode="int",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=SEED,
    validation_split=0.3,
    subset="validation"
)

val_batches = tf.data.experimental.cardinality(val_test_ds).numpy()
test_ds = val_test_ds.take(val_batches // 2)
val_ds = val_test_ds.skip(val_batches // 2)

train_ds = train_ds.map(lambda x, y: (tf.keras.applications.resnet.preprocess_input(x), y))
val_ds = val_ds.map(lambda x, y: (tf.keras.applications.resnet.preprocess_input(x), y))
test_ds = test_ds.map(lambda x, y: (tf.keras.applications.resnet.preprocess_input(x), y))

train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.prefetch(tf.data.AUTOTUNE)
test_ds = test_ds.prefetch(tf.data.AUTOTUNE)

print("Class order:", class_names)
print(f"Train batches: {len(train_ds)}")
print(f"Val batches: {len(val_ds)}")
print(f"Test batches: {len(test_ds)}")
# Out:
# TensorFlow version: 2.21.0
# Project root: c:\Users\k nithin\Downloads\M.Tech Project
# Found 59069 files belonging to 3 classes.
# Using 41349 files for training.
# Found 59069 files belonging to 3 classes.
# Using 17720 files for validation.
# Class order: ['anthra', 'healthy', 'rust']
# Train batches: 5169
# Val batches: 1108
# Test batches: 1107

# %% [markdown]
# ## Step 2: Load Saved KD Student & Build Inference Model

# %%
kd_student_path = os.path.join(SAVE_DIR, "densenet121_beans_distilled.keras")
print(f"Loading KD student from: {kd_student_path}")

source_student_model = tf.keras.models.load_model(kd_student_path, compile=False)
print(f"Loaded source model type: {type(source_student_model)}")
print(f"Source model outputs: {source_student_model.output_names}")

inference_model = tf.keras.Model(
    inputs=source_student_model.input,
    outputs=source_student_model.get_layer("bean_logits").output,
    name="densenet121_beans_logits_only"
)

print("\nInference model created")
print(f"Input shape: {inference_model.input_shape}")
print(f"Output shape: {inference_model.output_shape}")
print(f"Inference model class: {inference_model.__class__.__module__}.{inference_model.__class__.__name__}")
# Out:
# Loading KD student from: c:\Users\k nithin\Downloads\M.Tech Project\models\densenet121_beans_distilled.keras
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Loaded source model type: <class 'keras.src.models.functional.Functional'>
# Source model outputs: ListWrapper(['proj_0', 'proj_1', 'bean_logits'])
#
# Inference model created
# Input shape: (None, 224, 224, 3)
# Output shape: (None, 3)
# Inference model class: keras.src.models.functional.Functional

# %% [markdown]
# ## Step 3: Evaluate FP32 Baseline (Before Quantization)

# %%
def evaluate_model(model, test_dataset, model_name="Model"):
    """Evaluate Keras model on test set and return metrics."""
    y_true = []
    y_pred = []
    y_prob = []
    total_elapsed = 0.0
    total_images = 0

    for images, labels in test_dataset:
        start = time.perf_counter()
        outputs = model(images, training=False)
        elapsed = time.perf_counter() - start

        logits = outputs["logits"] if isinstance(outputs, dict) else outputs
        probs = tf.nn.softmax(logits)

        probs_np = probs.numpy()
        labels_np = labels.numpy()

        y_prob.extend(probs_np)
        y_pred.extend(np.argmax(probs_np, axis=1))
        y_true.extend(labels_np)

        total_elapsed += elapsed
        total_images += int(images.shape[0])

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    y_prob = np.array(y_prob)

    accuracy = accuracy_score(y_true, y_pred)
    avg_latency = total_elapsed / total_images if total_images else 0.0

    num_params = model.count_params() if hasattr(model, "count_params") else 0
    cm = confusion_matrix(y_true, y_pred)
    report = classification_report(y_true, y_pred, target_names=class_names, output_dict=True)

    print(f"\n{model_name} Evaluation:")
    print(f"  Accuracy: {accuracy:.4f}")
    print(f"  Avg Latency (per image): {avg_latency * 1000:.2f} ms")
    print(f"  Parameters: {num_params:,}")
    print(f"\nClassification Report:\n{classification_report(y_true, y_pred, target_names=class_names)}")

    return {
        'accuracy': accuracy,
        'latency_ms': avg_latency * 1000,
        'num_params': num_params,
        'y_true': y_true,
        'y_pred': y_pred,
        'y_prob': y_prob,
        'cm': cm,
        'report': report
    }

fp32_metrics = evaluate_model(inference_model, test_ds, "FP32 KD Student (Baseline)")
# Out:
# FP32 KD Student (Baseline) Evaluation:
#   Accuracy: 0.9370
#   Avg Latency (per image): 187.94 ms
#   Parameters: 7,041,619
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       anthra       0.96      0.99      0.97      2031
#      healthy       0.91      0.95      0.93      3794
#         rust       0.96      0.89      0.92      3031
#
#     accuracy                           0.94      8856
#    macro avg       0.94      0.94      0.94      8856
# weighted avg       0.94      0.94      0.94      8856

# %% [markdown]
# ## Step 4: Convert Saved Student to TFLite

# %%
def evaluate_tflite(tflite_model_path, test_dataset, model_name="TFLite Model"):
    """Evaluate TFLite model using interpreter."""
    interpreter = tf.lite.Interpreter(model_path=tflite_model_path)
    interpreter.allocate_tensors()

    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()

    print(f"Input details: {input_details[0]['shape']}, dtype: {input_details[0]['dtype']}")
    print(f"Output details: {output_details[0]['shape']}, dtype: {output_details[0]['dtype']}")

    input_scale, input_zero_point = input_details[0]['quantization']
    output_scale, output_zero_point = output_details[0]['quantization']
    if input_scale == 0:
        input_scale = 1.0
    if output_scale == 0:
        output_scale = 1.0

    y_true = []
    y_pred = []
    y_prob = []
    total_elapsed = 0.0
    total_images = 0

    for images, labels in test_dataset:
        batch_size = int(images.shape[0])

        interpreter.resize_tensor_input(input_details[0]['index'], [batch_size, 224, 224, 3])
        interpreter.allocate_tensors()

        if input_details[0]['dtype'] == np.int8:
            input_data = np.round(images.numpy() / input_scale + input_zero_point).astype(np.int8)
        elif input_details[0]['dtype'] == np.uint8:
            input_data = np.round(images.numpy() / input_scale + input_zero_point).astype(np.uint8)
        else:
            input_data = images.numpy().astype(input_details[0]['dtype'])

        interpreter.set_tensor(input_details[0]['index'], input_data)

        start = time.perf_counter()
        interpreter.invoke()
        elapsed = time.perf_counter() - start
        total_elapsed += elapsed
        total_images += batch_size

        output_data = interpreter.get_tensor(output_details[0]['index'])

        if output_details[0]['dtype'] in (np.int8, np.uint8):
            logits = (output_data.astype(np.float32) - output_zero_point) * output_scale
        else:
            logits = output_data.astype(np.float32)

        probs = tf.nn.softmax(logits)
        probs_np = probs.numpy()
        y_prob.extend(probs_np)
        y_pred.extend(np.argmax(probs_np, axis=1))
        y_true.extend(labels.numpy())

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    y_prob = np.array(y_prob)

    accuracy = accuracy_score(y_true, y_pred)
    avg_latency = total_elapsed / total_images if total_images else 0.0
    model_size_kb = os.path.getsize(tflite_model_path) / 1024
    cm = confusion_matrix(y_true, y_pred)

    print(f"\n{model_name} Evaluation:")
    print(f"  Accuracy: {accuracy:.4f}")
    print(f"  Avg Latency (per image): {avg_latency * 1000:.2f} ms")
    print(f"  Model Size: {model_size_kb:.2f} KB")
    print(f"\nClassification Report:\n{classification_report(y_true, y_pred, target_names=class_names)}")

    return {
        'accuracy': accuracy,
        'latency_ms': avg_latency * 1000,
        'model_size_kb': model_size_kb,
        'y_true': y_true,
        'y_pred': y_pred,
        'y_prob': y_prob,
        'cm': cm
    }

converter = tf.lite.TFLiteConverter.from_keras_model(inference_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]

def representative_data_gen():
    """Generate representative data for quantization."""
    count = 0
    for images, _ in train_ds:
        yield [tf.cast(images, tf.float32).numpy()]
        count += 1
        if count >= 10:
            break

converter.representative_dataset = representative_data_gen
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

print("Converting to TFLite...")
tflite_quantized_model = converter.convert()
print(f"Conversion complete. Model size: {len(tflite_quantized_model) / 1024:.2f} KB")

tflite_path = os.path.join(SAVE_DIR, "densenet121_beans_distilled_quantized.tflite")
with open(tflite_path, 'wb') as f:
    f.write(tflite_quantized_model)

print(f"TFLite model saved to: {tflite_path}")
# Out:
# Converting to TFLite...
# INFO:tensorflow:Assets written to: C:\Users\KNITHI~1\AppData\Local\Temp\tmpu1yrep80\assets
# INFO:tensorflow:Assets written to: C:\Users\KNITHI~1\AppData\Local\Temp\tmpu1yrep80\assets
# Saved artifact at 'C:\Users\KNITHI~1\AppData\Local\Temp\tmpu1yrep80'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   2318546512608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546622016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546624128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546617440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546619728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546631344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546632224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546631872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546665888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546672576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546670112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546674688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546671696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546673104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546678736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546681376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546681200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546679440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546731600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546738288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546735824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546740400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546737408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546738816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546745856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546746736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546829552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546746912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546830432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546837120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546834656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546839232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546836240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546837648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546845392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546897200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546895088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546895264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546896496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546903184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546900720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546905296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546902304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546903712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546908816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546993568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546996560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546993392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546995328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547002016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318546999552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547004128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547001136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547002544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547007648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547092048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547095392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547091520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547094160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547100848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547098384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547102960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547099968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547101376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547106480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547241264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547243376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547239504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547242144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547248832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547248656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547252000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547250064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547250768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547251296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547290416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547292528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547288832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547290944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547297984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547295520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547301680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547297808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547300448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547300976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548435360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548439936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548436240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548438352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548445392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548442928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548449088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548445216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548447856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548448384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548534192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548538768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548535776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548537184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548544224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548541760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548547920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548544048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548546688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548547216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548616640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548621216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548618224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548619632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548626672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548624208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548630368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548626496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548629136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548629664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548699088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548703664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548700672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548702080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548709120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548706656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548712816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548708944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548711584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548712112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548781536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548786112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548783120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548784528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548791568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548789104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548788400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548791392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548794032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548866448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548863984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548868560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548865568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548866976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548874016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548874544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548870848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548873840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548876480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548965280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548962816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548967392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548964400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548965808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548972848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548973376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548969680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548972672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548975312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549047728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549045264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549049840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549046848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549048256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549055296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549055824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549057056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549055120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549123488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549130176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549127712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549132288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549129296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549130704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549137744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549138624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549188672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549138800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549189552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549196240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549193776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549198352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549195360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549196768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549203808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549254736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549254208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549254384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549255616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549262304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549259840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549264416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549261424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549262832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549267936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549352688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549352864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549352512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549354448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549361136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549362192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549364480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549362368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549363248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318549368000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547355952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547354896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547353840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547355424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547362464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547360000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547366160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547362288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547364928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547369680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547455312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547455840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547452144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547454256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547461296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547458832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547464992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547461120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547463760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547464288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547536176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547538288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547534592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547536704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547543744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547541280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547547440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547543568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547546208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547546736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547648928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547653504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547649808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547651920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547658960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547656496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547662656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547658784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547661424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547661952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547698608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547703184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547700192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547701600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547708640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547706176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547712336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547708464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547711104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547711632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547781056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547785632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547782640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547784048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547791088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547788624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547794784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547790912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547793552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547794080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547863504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547868080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547865088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547866496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547873536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547871072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547877232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547873360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547876000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547876528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547945952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547950528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547947536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547948944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547955984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547953520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547952816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547955808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318547958448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548047248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548044784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548049360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548046368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548047776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548054816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548055344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548051648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548054640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548057280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548129696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548127232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548131808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548128816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548130224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548137264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548137792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548134096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548137088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548139728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548212144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548209680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548214256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548211264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548212672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548219712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548220240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548221472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548219536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548287904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548294592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548292128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548296704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548293712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548295120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548302160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548303040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548385856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548303216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548386736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548393424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548390960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548395536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548392544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548393952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318548400992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595031632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595031104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595031280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595032512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595039200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595036736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595041312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595038320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595039728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595044832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595129584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595129760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595129408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595131344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595138032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595135568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595140144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595137152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595138560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595143664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595227712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595231408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595228592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595230176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595236864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595234400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595238976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595235984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595237392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595242496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595326720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595330240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595326368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595329008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595335696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595333232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595337808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595334816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595336224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595341328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595391552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595396304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595392432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595395072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595401760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595399296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595403872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595400880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595402288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595407392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595473472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595478752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595474880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595477520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595484208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595481744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595486320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595483328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595484736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595484032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595588688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595593968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595590096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595592736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595599424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595596960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595601536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595598544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595599952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595599248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595653872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595660032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595656160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595658800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595665488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595663024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595667600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595664608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595666016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595665312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595736320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595742480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595738608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595741248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595747936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595745472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595750048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595747056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595748464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595747760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595818768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595824928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595821056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595823696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595830384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595827920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595832496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595829504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595830912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595830208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595917600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595923760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595919888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595922528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595929216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595926752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595931328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595928336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595929744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595929040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595983664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595989824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595985952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595988592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595995280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595995632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595989472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595996512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318595997392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621120944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621118480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621123056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621120064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621121472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621128512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621129040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621130272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621128336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621213088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621219776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621217312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621221888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621218896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621220304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621227344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621228224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621294656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621228400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621295536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621302224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621299760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621304336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621301344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621302752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621309792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621377104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621376576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621376752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621377984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621384672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621382208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621386784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621383792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621385200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621390304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621475056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621475232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621474880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621476816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621483504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621481040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621485616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621482624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621484032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621489136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621540416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621544112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621541296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621542880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621549568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621547104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621551680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621548688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621550096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621555200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621606656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621610176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621606304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621608944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621615632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621613168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621617744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621614752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621616160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621621264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621737024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621741776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621737904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621740544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621747232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621744768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621749344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621746352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621747760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621752864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621818944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621824224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621820352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621822992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621829680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621827216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621831792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621828800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621830208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621829504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621885008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621890288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621886416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621889056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621895744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621893280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621897856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621894864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621896272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621895568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621966576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621972736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621968864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621971504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621978192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621975728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621980304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621977312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621978720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318621978016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318622098176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318622104336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318622100464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318622103104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318622109792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318622107328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318622111904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318622108912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318622110320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318622109616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318638990608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318638996768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318638992896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318638995536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639002224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318638999760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639004336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639001344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639002752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639002048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639089440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639095600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639091728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639094368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639101056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639098592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639103168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639100176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639101584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639100880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639155504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639161664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639157792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639160432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639167120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639164656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639169232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639166240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639167648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639166944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639254336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639260496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639256624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639259264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639265952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639263488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639262784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639265072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639266480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639339248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639336784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639342944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639339072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639341712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639347696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639348400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639422928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2318639423280: TensorSpec(shape=(), dtype=tf.resource, name=None)
# c:\Users\k nithin\Downloads\M.Tech Project\.venv\lib\site-packages\tensorflow\lite\python\convert.py:846: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Conversion complete. Model size: 7211.10 KB
# TFLite model saved to: c:\Users\k nithin\Downloads\M.Tech Project\models\densenet121_beans_distilled_quantized.tflite

# %% [markdown]
# ## Step 5: Evaluate TFLite Model

# %%
tflite_metrics = evaluate_tflite(tflite_path, test_ds, "TFLite Quantized Model")
# Out:
# c:\Users\k nithin\Downloads\M.Tech Project\.venv\lib\site-packages\tensorflow\lite\python\interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# Input details: [  1 224 224   3], dtype: <class 'numpy.int8'>
# Output details: [1 3], dtype: <class 'numpy.int8'>
#
# TFLite Quantized Model Evaluation:
#   Accuracy: 0.3681
#   Avg Latency (per image): 175.39 ms
#   Model Size: 7211.10 KB
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       anthra       0.27      0.99      0.42      2035
#      healthy       0.50      0.01      0.02      3788
#         rust       0.94      0.40      0.56      3033
#
#     accuracy                           0.37      8856
#    macro avg       0.57      0.47      0.33      8856
# weighted avg       0.60      0.37      0.30      8856

# %% [markdown]
# ## Step 6: Comparison - FP32 vs QAT vs TFLite

# %%
fp32_model_size_kb = os.path.getsize(kd_student_path) / 1024
quantized_model_size_kb = os.path.getsize(tflite_path) / 1024

comparison_df = pd.DataFrame({
    'Model': ['FP32 KD Student', 'INT8 Quantized'],
    'Accuracy': [
        fp32_metrics['accuracy'],
        tflite_metrics['accuracy']
    ],
    'Latency (ms)': [
        fp32_metrics['latency_ms'],
        tflite_metrics['latency_ms']
    ],
    'Model Size (KB)': [
        fp32_model_size_kb,
        quantized_model_size_kb
    ]
})

print("\n" + "="*80)
print("COMPARISON: FP32 vs INT8")
print("="*80)
print(comparison_df.to_string(index=False))
print("="*80)

accuracy_drop = (fp32_metrics['accuracy'] - tflite_metrics['accuracy']) * 100
size_reduction = ((fp32_model_size_kb - quantized_model_size_kb) / fp32_model_size_kb) * 100
latency_improvement = ((fp32_metrics['latency_ms'] - tflite_metrics['latency_ms']) / fp32_metrics['latency_ms']) * 100 if fp32_metrics['latency_ms'] else 0.0

print(f"\nMetrics:")
print(f"  Accuracy drop (FP32 → INT8): {accuracy_drop:.2f}%")
print(f"  Model size reduction: {size_reduction:.2f}%")
print(f"  Latency improvement: {latency_improvement:.2f}%")

comparison_csv_path = os.path.join(RESULTS_DIR, "densenet121_kd_quantization_comparison.csv")
comparison_df.to_csv(comparison_csv_path, index=False)
print(f"\nComparison saved to: {comparison_csv_path}")
# Out:
# ================================================================================
# COMPARISON: FP32 vs INT8
# ================================================================================
#           Model  Accuracy  Latency (ms)  Model Size (KB)
# FP32 KD Student  0.936992    187.944815     41287.708008
#  INT8 Quantized  0.368112    175.387931      7211.101562
# ================================================================================
#
# Metrics:
#   Accuracy drop (FP32 → INT8): 56.89%
#   Model size reduction: 82.53%
#   Latency improvement: 6.68%
#
# Comparison saved to: c:\Users\k nithin\Downloads\M.Tech Project\results\quantization\densenet121_kd_quantization_comparison.csv

# %% [markdown]
# ## Step 7: Visualizations

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

for idx, (cm, title) in enumerate([
    (fp32_metrics['cm'], 'FP32 KD Student'),
    (tflite_metrics['cm'], 'INT8 Quantized')
]):
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[idx],
                xticklabels=class_names, yticklabels=class_names)
    axes[idx].set_title(title)
    axes[idx].set_xlabel('Predicted')
    axes[idx].set_ylabel('True')

plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "densenet121_kd_quantization_confusion_matrices.png"), dpi=150, bbox_inches='tight')
plt.show()

print(f"Confusion matrices saved")
# Out:
# Confusion matrices saved

# %%
fig, ax = plt.subplots(figsize=(7, 5))

models = ['FP32\nBaseline', 'INT8\nQuantized']
accuracies = [
    fp32_metrics['accuracy'],
    tflite_metrics['accuracy']
]

bars = ax.bar(models, accuracies, color=['#1f77b4', '#2ca02c'], alpha=0.7, edgecolor='black')
ax.set_ylabel('Accuracy', fontsize=12)
ax.set_title('Accuracy Comparison: FP32 vs INT8', fontsize=14, fontweight='bold')
ax.set_ylim([min(accuracies) - 0.05, 1.05])
ax.grid(axis='y', alpha=0.3)

for bar, acc in zip(bars, accuracies):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2., height,
            f'{acc:.4f}',
            ha='center', va='bottom', fontsize=11, fontweight='bold')

plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "densenet121_kd_quantization_accuracy_comparison.png"), dpi=150, bbox_inches='tight')
plt.show()

print(f"Accuracy comparison plot saved")
# Out:
# Accuracy comparison plot saved

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 5))

models = ['FP32\nBaseline', 'INT8\nQuantized']
sizes = [
    fp32_model_size_kb / 1024,
    quantized_model_size_kb / 1024
]
latencies = [
    fp32_metrics['latency_ms'],
    tflite_metrics['latency_ms']
]

bars1 = ax1.bar(models, sizes, color=['#1f77b4', '#2ca02c'], alpha=0.7, edgecolor='black')
ax1.set_ylabel('Model Size (MB)', fontsize=12)
ax1.set_title('Model Size Comparison', fontsize=13, fontweight='bold')
ax1.grid(axis='y', alpha=0.3)

for bar, size in zip(bars1, sizes):
    height = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2., height,
            f'{size:.2f}',
            ha='center', va='bottom', fontsize=10, fontweight='bold')

bars2 = ax2.bar(models, latencies, color=['#1f77b4', '#2ca02c'], alpha=0.7, edgecolor='black')
ax2.set_ylabel('Latency (ms)', fontsize=12)
ax2.set_title('Inference Latency (per image)', fontsize=13, fontweight='bold')
ax2.grid(axis='y', alpha=0.3)

for bar, lat in zip(bars2, latencies):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height,
            f'{lat:.2f}',
            ha='center', va='bottom', fontsize=10, fontweight='bold')

plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "densenet121_kd_quantization_size_latency.png"), dpi=150, bbox_inches='tight')
plt.show()

print(f"Size and latency comparison plots saved")
# Out:
# Size and latency comparison plots saved

# %% [markdown]
# ## Summary

# %%
print("\n" + "="*80)
print("QUANTIZATION SUMMARY")
print("="*80)
print(f"\n✓ FP32 baseline loaded and evaluated")
print(f"  - Accuracy: {fp32_metrics['accuracy']:.4f}")
print(f"  - Model size: {fp32_model_size_kb / 1024:.2f} MB")

print(f"\n✓ INT8 quantization completed")
print(f"  - Accuracy: {tflite_metrics['accuracy']:.4f}")
print(f"  - Accuracy drop: {(fp32_metrics['accuracy'] - tflite_metrics['accuracy']) * 100:.2f}%")
print(f"  - Model size: {quantized_model_size_kb / 1024:.2f} MB")
print(f"  - Size reduction: {size_reduction:.2f}%")
print(f"  - Latency improvement: {latency_improvement:.2f}%")

print(f"\n✓ Results saved to: {RESULTS_DIR}")
print(f"  - CSV: densenet121_kd_quantization_comparison.csv")
print(f"  - Plots: confusion_matrices, accuracy_comparison, size_latency")
print(f"\n✓ Models saved to: {SAVE_DIR}")
print(f"  - densenet121_beans_distilled_quantized.tflite")
print("\n" + "="*80)
# Out:
# ================================================================================
# QUANTIZATION SUMMARY
# ================================================================================
#
# ✓ FP32 baseline loaded and evaluated
#   - Accuracy: 0.9370
#   - Model size: 40.32 MB
#
# ✓ INT8 quantization completed
#   - Accuracy: 0.3681
#   - Accuracy drop: 56.89%
#   - Model size: 7.04 MB
#   - Size reduction: 82.53%
#   - Latency improvement: 6.68%
#
# ✓ Results saved to: c:\Users\k nithin\Downloads\M.Tech Project\results\quantization
#   - CSV: densenet121_kd_quantization_comparison.csv
#   - Plots: confusion_matrices, accuracy_comparison, size_latency
#
# ✓ Models saved to: c:\Users\k nithin\Downloads\M.Tech Project\models
#   - densenet121_beans_distilled_quantized.tflite
#
# ================================================================================

# %% [markdown]
# ## Code
