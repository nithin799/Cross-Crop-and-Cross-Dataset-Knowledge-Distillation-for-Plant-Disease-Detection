# %% [markdown]
# # EfficientNetB1 KD Quantization: Direct Quantization of Saved Student Model
#
# This notebook loads the saved EfficientNetB1 student trained via knowledge distillation and applies post-training quantization without retraining. We compare:
# - FP32 KD student baseline
# - TFLite quantized model
#
# Metrics: accuracy, model size, inference latency

# %% [markdown]
# ## Step 1: Setup & Imports

# %%
import os
import time
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

print(f"TensorFlow version: {tf.__version__}")

current_dir = os.getcwd()
project_root = current_dir
while not (os.path.exists(os.path.join(project_root, 'Beans dataset')) and 
           os.path.exists(os.path.join(project_root, 'models'))):
    project_root = os.path.dirname(project_root)
    if project_root == os.path.dirname(project_root):
        raise RuntimeError("Could not find project root")

print(f"Project root: {project_root}")

DATA_DIR = os.path.join(project_root, "Beans dataset")
SAVE_DIR = os.path.join(project_root, "models")
RESULTS_DIR = os.path.join(project_root, "results", "quantization")
os.makedirs(RESULTS_DIR, exist_ok=True)

IMG_SIZE = (224, 224)
BATCH_SIZE = 8
SEED = 42
NUM_CLASSES = 3

train_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    labels="inferred",
    label_mode="int",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=SEED,
    validation_split=0.3,
    subset="training"
)
class_names = train_ds.class_names

val_test_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    labels="inferred",
    label_mode="int",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=SEED,
    validation_split=0.3,
    subset="validation"
)

val_batches = tf.data.experimental.cardinality(val_test_ds).numpy()
test_ds = val_test_ds.take(val_batches // 2)
val_ds = val_test_ds.skip(val_batches // 2)

train_ds = train_ds.map(lambda x, y: (tf.keras.applications.resnet.preprocess_input(x), y))
val_ds = val_ds.map(lambda x, y: (tf.keras.applications.resnet.preprocess_input(x), y))
test_ds = test_ds.map(lambda x, y: (tf.keras.applications.resnet.preprocess_input(x), y))

train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.prefetch(tf.data.AUTOTUNE)
test_ds = test_ds.prefetch(tf.data.AUTOTUNE)

print("Class order:", class_names)
print(f"Train batches: {len(train_ds)}")
print(f"Val batches: {len(val_ds)}")
print(f"Test batches: {len(test_ds)}")
# Out:
# TensorFlow version: 2.21.0
# Project root: c:\Users\k nithin\Downloads\M.Tech Project
# Found 59069 files belonging to 3 classes.
# Using 41349 files for training.
# Found 59069 files belonging to 3 classes.
# Using 17720 files for validation.
# Class order: ['anthra', 'healthy', 'rust']
# Train batches: 5169
# Val batches: 1108
# Test batches: 1107

# %% [markdown]
# ## Step 2: Load Saved KD Student & Build Inference Model

# %%
kd_student_path = os.path.join(SAVE_DIR, "efficientb1_beans_distilled.keras")
print(f"Loading KD student from: {kd_student_path}")

source_student_model = tf.keras.models.load_model(kd_student_path, compile=False)
print(f"Loaded source model type: {type(source_student_model)}")
print(f"Source model outputs: {source_student_model.output_names}")

inference_model = tf.keras.Model(
    inputs=source_student_model.input,
    outputs=source_student_model.get_layer("dense_1").output,
    name="efficientnetb1_beans_logits_only"
)

print("\nInference model created")
print(f"Input shape: {inference_model.input_shape}")
print(f"Output shape: {inference_model.output_shape}")
print(f"Inference model class: {inference_model.__class__.__module__}.{inference_model.__class__.__name__}")
# Out:
# Loading KD student from: c:\Users\k nithin\Downloads\M.Tech Project\models\efficientb1_beans_distilled.keras
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Loaded source model type: <class 'keras.src.models.functional.Functional'>
# Source model outputs: ListWrapper(['proj_0', 'proj_1', 'dense_1'])
#
# Inference model created
# Input shape: (None, 224, 224, 3)
# Output shape: (None, 3)
# Inference model class: keras.src.models.functional.Functional

# %% [markdown]
# ## Step 3: Evaluate FP32 Baseline (Before Quantization)

# %%
def evaluate_model(model, test_dataset, model_name="Model"):
    """Evaluate Keras model on test set and return metrics."""
    y_true = []
    y_pred = []
    y_prob = []
    total_elapsed = 0.0
    total_images = 0

    for images, labels in test_dataset:
        start = time.perf_counter()
        outputs = model(images, training=False)
        elapsed = time.perf_counter() - start

        logits = outputs["logits"] if isinstance(outputs, dict) else outputs
        probs = tf.nn.softmax(logits)

        probs_np = probs.numpy()
        labels_np = labels.numpy()

        y_prob.extend(probs_np)
        y_pred.extend(np.argmax(probs_np, axis=1))
        y_true.extend(labels_np)

        total_elapsed += elapsed
        total_images += int(images.shape[0])

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    y_prob = np.array(y_prob)

    accuracy = accuracy_score(y_true, y_pred)
    avg_latency = total_elapsed / total_images if total_images else 0.0

    num_params = model.count_params() if hasattr(model, "count_params") else 0
    cm = confusion_matrix(y_true, y_pred)
    report = classification_report(y_true, y_pred, target_names=class_names, output_dict=True)

    print(f"\n{model_name} Evaluation:")
    print(f"  Accuracy: {accuracy:.4f}")
    print(f"  Avg Latency (per image): {avg_latency * 1000:.2f} ms")
    print(f"  Parameters: {num_params:,}")
    print(f"\nClassification Report:\n{classification_report(y_true, y_pred, target_names=class_names)}")

    return {
        'accuracy': accuracy,
        'latency_ms': avg_latency * 1000,
        'num_params': num_params,
        'y_true': y_true,
        'y_pred': y_pred,
        'y_prob': y_prob,
        'cm': cm,
        'report': report
    }

fp32_metrics = evaluate_model(inference_model, test_ds, "FP32 KD Student (Baseline)")
# Out:
# FP32 KD Student (Baseline) Evaluation:
#   Accuracy: 0.9638
#   Avg Latency (per image): 162.86 ms
#   Parameters: 7,232,650
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       anthra       0.97      0.98      0.98      2031
#      healthy       0.95      0.97      0.96      3794
#         rust       0.98      0.94      0.96      3031
#
#     accuracy                           0.96      8856
#    macro avg       0.97      0.96      0.97      8856
# weighted avg       0.96      0.96      0.96      8856

# %% [markdown]
# ## Step 4: Convert Saved Student to TFLite

# %%
def evaluate_tflite(tflite_model_path, test_dataset, model_name="TFLite Model"):
    """Evaluate TFLite model using interpreter."""
    interpreter = tf.lite.Interpreter(model_path=tflite_model_path)
    interpreter.allocate_tensors()

    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()

    print(f"Input details: {input_details[0]['shape']}, dtype: {input_details[0]['dtype']}")
    print(f"Output details: {output_details[0]['shape']}, dtype: {output_details[0]['dtype']}")

    input_scale, input_zero_point = input_details[0]['quantization']
    output_scale, output_zero_point = output_details[0]['quantization']
    if input_scale == 0:
        input_scale = 1.0
    if output_scale == 0:
        output_scale = 1.0

    y_true = []
    y_pred = []
    y_prob = []
    total_elapsed = 0.0
    total_images = 0

    for images, labels in test_dataset:
        batch_size = int(images.shape[0])

        interpreter.resize_tensor_input(input_details[0]['index'], [batch_size, 224, 224, 3])
        interpreter.allocate_tensors()

        if input_details[0]['dtype'] == np.int8:
            input_data = np.round(images.numpy() / input_scale + input_zero_point).astype(np.int8)
        elif input_details[0]['dtype'] == np.uint8:
            input_data = np.round(images.numpy() / input_scale + input_zero_point).astype(np.uint8)
        else:
            input_data = images.numpy().astype(input_details[0]['dtype'])

        interpreter.set_tensor(input_details[0]['index'], input_data)

        start = time.perf_counter()
        interpreter.invoke()
        elapsed = time.perf_counter() - start
        total_elapsed += elapsed
        total_images += batch_size

        output_data = interpreter.get_tensor(output_details[0]['index'])

        if output_details[0]['dtype'] in (np.int8, np.uint8):
            logits = (output_data.astype(np.float32) - output_zero_point) * output_scale
        else:
            logits = output_data.astype(np.float32)

        probs = tf.nn.softmax(logits)
        probs_np = probs.numpy()
        y_prob.extend(probs_np)
        y_pred.extend(np.argmax(probs_np, axis=1))
        y_true.extend(labels.numpy())

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    y_prob = np.array(y_prob)

    accuracy = accuracy_score(y_true, y_pred)
    avg_latency = total_elapsed / total_images if total_images else 0.0
    model_size_kb = os.path.getsize(tflite_model_path) / 1024
    cm = confusion_matrix(y_true, y_pred)

    print(f"\n{model_name} Evaluation:")
    print(f"  Accuracy: {accuracy:.4f}")
    print(f"  Avg Latency (per image): {avg_latency * 1000:.2f} ms")
    print(f"  Model Size: {model_size_kb:.2f} KB")
    print(f"\nClassification Report:\n{classification_report(y_true, y_pred, target_names=class_names)}")

    return {
        'accuracy': accuracy,
        'latency_ms': avg_latency * 1000,
        'model_size_kb': model_size_kb,
        'y_true': y_true,
        'y_pred': y_pred,
        'y_prob': y_prob,
        'cm': cm
    }

converter = tf.lite.TFLiteConverter.from_keras_model(inference_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]

def representative_data_gen():
    """Generate representative data for quantization."""
    count = 0
    for images, _ in train_ds:
        yield [tf.cast(images, tf.float32).numpy()]
        count += 1
        if count >= 10:
            break

converter.representative_dataset = representative_data_gen
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

print("Converting to TFLite...")
tflite_quantized_model = converter.convert()
print(f"Conversion complete. Model size: {len(tflite_quantized_model) / 1024:.2f} KB")

tflite_path = os.path.join(SAVE_DIR, "efficientnetb1_beans_distilled_quantized.tflite")
with open(tflite_path, 'wb') as f:
    f.write(tflite_quantized_model)

print(f"TFLite model saved to: {tflite_path}")
# Out:
# Converting to TFLite...
# INFO:tensorflow:Assets written to: C:\Users\KNITHI~1\AppData\Local\Temp\tmp9sfy7i_b\assets
# INFO:tensorflow:Assets written to: C:\Users\KNITHI~1\AppData\Local\Temp\tmp9sfy7i_b\assets
# Saved artifact at 'C:\Users\KNITHI~1\AppData\Local\Temp\tmp9sfy7i_b'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   2279752803504: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   2280242806848: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   2278625206240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278625210464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278625210992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278625208880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278625209760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278625214160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660786656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660787360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660785952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660786480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660795984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660793872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660798800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660796512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660795456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660834048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660837920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660836336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660836864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660842144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660840208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660844080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660841968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660842672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660842320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278625205888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660953664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660951904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660958064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660956128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660960000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660957888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660958592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278660959824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661047744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661051616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661049504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661050208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661058832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661056896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661060768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661058656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661059360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661059008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661118560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661121376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661119088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661125776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661123840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661127712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661125600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661126304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661125952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661212112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661215984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661213872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661214576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661221616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661219680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661223552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661221440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661222144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661221792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661330496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661333312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661331024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661337712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661335776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661339648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661337536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661338240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661339472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661411184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661415056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661412944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661413648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661420688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661418752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661422624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661420512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661421216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661420864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661480416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661483232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661480944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661487632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661483408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661482352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661487280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661486752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661563040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661561104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661564976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661562864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661563568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661570080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661654304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661655712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661654656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661655184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661664688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661662576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661667504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661661872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661663632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661719312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661723184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661721072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661721776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661727408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661725472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661729344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661727232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661727936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661732864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661733920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278632900736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278661734096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278632898800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278632909712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278632907600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278632912528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278632910240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278632909184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278632980720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278632982656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278632983008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278632983536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278632992336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278632990400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278632994272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278632992160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278632992864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278632992512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633096464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633100336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633098224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633098928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633108784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633106672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633109312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633108256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633108608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633179792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633183664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633181552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633182256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633191408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633189472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633188064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633191232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633191936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633191584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633264352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633268224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633266112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633266816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633274560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633273856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633273504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633345216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633349616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633347680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633351552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633349440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633350144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633355776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633352608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633352432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633355424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633352784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633461840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633459904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633463776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633461664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633462368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633470112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633469408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633469056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633557152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633561552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633559616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633563488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633561376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633562080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633569120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633605600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633604544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633604192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633605072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633611760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633609824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633613696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633611584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633612288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633611936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633619152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633690688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633688752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633695088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633693152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633697024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633694912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633695616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633696848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633768560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633772432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633770320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633771024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633778064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633776128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633780000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633777888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633778592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633778240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633886944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633889760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633887472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633894160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633892224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633896096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633893984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633894688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633895920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634999824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635003696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635001584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635002288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635009328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635007392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635011264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635009152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635009856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635009504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635101824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635104640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635102352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635109040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635104816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635103760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635108688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635105344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635148160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635146224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635150096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635147984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635148688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635155728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635153792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635157664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635155552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635156256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635155904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635248224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635251040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635248752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635255440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635253504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635257376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635255264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635255968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635363616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635361680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635365552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635363440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635364144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635371184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635368016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635367840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635370832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635368192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635430912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635422464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635433728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635431440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635436016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635437776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635437248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635436544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635503680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635513536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635511600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635515472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635513360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635514064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635518992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635588240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635587184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635586832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635587712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635597216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635595104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635600032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635597744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635596688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635700992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635704864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635703280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635703808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635712608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635710672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635714544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635712432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635713136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635712784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635785552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635789424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635787312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635788016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635797872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635787664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635795232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635796992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635796288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635836112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635839984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635837872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635838576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635844208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635842272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635846144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635844032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635844736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635844384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635948336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635952208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635950096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635950800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635960656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635958544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635961184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635960128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278635960480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633934512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633938384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633936272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633936976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633946128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633942960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633942784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633945776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633945248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633986656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633984720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633988592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633986480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633987184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633994928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633994224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278633993872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634081968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634086368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634084432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634088304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634086192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634086896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634093936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634194544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634195952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634194896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634195424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634202112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634200176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634204048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634201936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634202640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634202288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634278224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634281040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634278752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634285440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634283504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634287376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634285264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634285968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634287200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634342528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634346400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634344288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634344992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634352032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634350096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634353968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634351856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634352560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634352208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634428144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634430960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634428672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634435360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634433424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634437296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634435184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634435888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634437120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634541600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634545472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634543360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634544064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634551104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634549168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634553040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634550928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634551632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634551280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634627216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634630032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634627744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634634432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634630208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634629152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634634080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634633552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634706320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634704384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634708256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634706144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634706848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634713888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634711952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634715824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634713712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634714416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634714064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634806384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634809200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634806912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634813600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634811664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634808320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634813424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634814128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634856240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634854304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634858176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634856064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634856768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634863104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278634863808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278724474960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2278724475312: TensorSpec(shape=(), dtype=tf.resource, name=None)
# c:\Users\k nithin\Downloads\M.Tech Project\.venv\lib\site-packages\tensorflow\lite\python\convert.py:846: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Conversion complete. Model size: 8352.55 KB
# TFLite model saved to: c:\Users\k nithin\Downloads\M.Tech Project\models\efficientnetb1_beans_distilled_quantized.tflite

# %% [markdown]
# ## Step 5: Evaluate TFLite Model

# %%
tflite_metrics = evaluate_tflite(tflite_path, test_ds, "TFLite Quantized Model")
# Out:
# Input details: [  1 224 224   3], dtype: <class 'numpy.int8'>
# Output details: [1 3], dtype: <class 'numpy.int8'>
# c:\Users\k nithin\Downloads\M.Tech Project\.venv\lib\site-packages\tensorflow\lite\python\interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# TFLite Quantized Model Evaluation:
#   Accuracy: 0.8292
#   Avg Latency (per image): 54.98 ms
#   Model Size: 8352.55 KB
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       anthra       1.00      0.64      0.78      2035
#      healthy       0.78      0.96      0.86      3788
#         rust       0.84      0.79      0.81      3033
#
#     accuracy                           0.83      8856
#    macro avg       0.87      0.80      0.82      8856
# weighted avg       0.85      0.83      0.83      8856

# %% [markdown]
# ## Step 6: Comparison - FP32 vs QAT vs TFLite

# %%
fp32_model_size_kb = os.path.getsize(kd_student_path) / 1024
quantized_model_size_kb = os.path.getsize(tflite_path) / 1024

comparison_df = pd.DataFrame({
    'Model': ['FP32 KD Student', 'INT8 Quantized'],
    'Accuracy': [
        fp32_metrics['accuracy'],
        tflite_metrics['accuracy']
    ],
    'Latency (ms)': [
        fp32_metrics['latency_ms'],
        tflite_metrics['latency_ms']
    ],
    'Model Size (KB)': [
        fp32_model_size_kb,
        quantized_model_size_kb
    ]
})

print("\n" + "="*80)
print("COMPARISON: FP32 vs INT8")
print("="*80)
print(comparison_df.to_string(index=False))
print("="*80)

accuracy_drop = (fp32_metrics['accuracy'] - tflite_metrics['accuracy']) * 100
size_reduction = ((fp32_model_size_kb - quantized_model_size_kb) / fp32_model_size_kb) * 100
latency_improvement = ((fp32_metrics['latency_ms'] - tflite_metrics['latency_ms']) / fp32_metrics['latency_ms']) * 100 if fp32_metrics['latency_ms'] else 0.0

print(f"\nMetrics:")
print(f"  Accuracy drop (FP32 → INT8): {accuracy_drop:.2f}%")
print(f"  Model size reduction: {size_reduction:.2f}%")
print(f"  Latency improvement: {latency_improvement:.2f}%")

comparison_csv_path = os.path.join(RESULTS_DIR, "efficientnetb1_kd_quantization_comparison.csv")
comparison_df.to_csv(comparison_csv_path, index=False)
print(f"\nComparison saved to: {comparison_csv_path}")
# Out:
# ================================================================================
# COMPARISON: FP32 vs INT8
# ================================================================================
#           Model  Accuracy  Latency (ms)  Model Size (KB)
# FP32 KD Student  0.963753    162.858506     40120.989258
#  INT8 Quantized  0.829155     54.977817      8352.546875
# ================================================================================
#
# Metrics:
#   Accuracy drop (FP32 → INT8): 13.46%
#   Model size reduction: 79.18%
#   Latency improvement: 66.24%
#
# Comparison saved to: c:\Users\k nithin\Downloads\M.Tech Project\results\quantization\efficientnetb1_kd_quantization_comparison.csv

# %% [markdown]
# ## Step 7: Visualizations

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

for idx, (cm, title) in enumerate([
    (fp32_metrics['cm'], 'FP32 KD Student'),
    (tflite_metrics['cm'], 'INT8 Quantized')
]):
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[idx],
                xticklabels=class_names, yticklabels=class_names)
    axes[idx].set_title(title)
    axes[idx].set_xlabel('Predicted')
    axes[idx].set_ylabel('True')

plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "efficientnetb1_kd_quantization_confusion_matrices.png"), dpi=150, bbox_inches='tight')
plt.show()

print(f"Confusion matrices saved")
# Out:
# Confusion matrices saved

# %%
fig, ax = plt.subplots(figsize=(7, 5))

models = ['FP32\nBaseline', 'INT8\nQuantized']
accuracies = [
    fp32_metrics['accuracy'],
    tflite_metrics['accuracy']
]

bars = ax.bar(models, accuracies, color=['#1f77b4', '#2ca02c'], alpha=0.7, edgecolor='black')
ax.set_ylabel('Accuracy', fontsize=12)
ax.set_title('Accuracy Comparison: FP32 vs INT8', fontsize=14, fontweight='bold')
ax.set_ylim([min(accuracies) - 0.05, 1.05])
ax.grid(axis='y', alpha=0.3)

for bar, acc in zip(bars, accuracies):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2., height,
            f'{acc:.4f}',
            ha='center', va='bottom', fontsize=11, fontweight='bold')

plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "efficientnetb1_kd_quantization_accuracy_comparison.png"), dpi=150, bbox_inches='tight')
plt.show()

print(f"Accuracy comparison plot saved")
# Out:
# Accuracy comparison plot saved

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 5))

models = ['FP32\nBaseline', 'INT8\nQuantized']
sizes = [
    fp32_model_size_kb / 1024,
    quantized_model_size_kb / 1024
]
latencies = [
    fp32_metrics['latency_ms'],
    tflite_metrics['latency_ms']
]

bars1 = ax1.bar(models, sizes, color=['#1f77b4', '#2ca02c'], alpha=0.7, edgecolor='black')
ax1.set_ylabel('Model Size (MB)', fontsize=12)
ax1.set_title('Model Size Comparison', fontsize=13, fontweight='bold')
ax1.grid(axis='y', alpha=0.3)

for bar, size in zip(bars1, sizes):
    height = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2., height,
            f'{size:.2f}',
            ha='center', va='bottom', fontsize=10, fontweight='bold')

bars2 = ax2.bar(models, latencies, color=['#1f77b4', '#2ca02c'], alpha=0.7, edgecolor='black')
ax2.set_ylabel('Latency (ms)', fontsize=12)
ax2.set_title('Inference Latency (per image)', fontsize=13, fontweight='bold')
ax2.grid(axis='y', alpha=0.3)

for bar, lat in zip(bars2, latencies):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height,
            f'{lat:.2f}',
            ha='center', va='bottom', fontsize=10, fontweight='bold')

plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "efficientnetb1_kd_quantization_size_latency.png"), dpi=150, bbox_inches='tight')
plt.show()

print(f"Size and latency comparison plots saved")
# Out:
# Size and latency comparison plots saved

# %% [markdown]
# ## Summary

# %%
print("\n" + "="*80)
print("QUANTIZATION SUMMARY")
print("="*80)
print(f"\n✓ FP32 baseline loaded and evaluated")
print(f"  - Accuracy: {fp32_metrics['accuracy']:.4f}")
print(f"  - Model size: {fp32_model_size_kb / 1024:.2f} MB")

print(f"\n✓  quantization completed")
print(f"  - Accuracy: {tflite_metrics['accuracy']:.4f}")
print(f"  - Accuracy drop: {(fp32_metrics['accuracy'] - tflite_metrics['accuracy']) * 100:.2f}%")
print(f"  - Model size: {quantized_model_size_kb / 1024:.2f} MB")
print(f"  - Size reduction: {size_reduction:.2f}%")
print(f"  - Latency improvement: {latency_improvement:.2f}%")

print(f"\n✓ Results saved to: {RESULTS_DIR}")
print(f"  - CSV: efficientnetb1_kd_quantization_comparison.csv")
print(f"  - Plots: confusion_matrices, accuracy_comparison, size_latency")
print(f"\n✓ Models saved to: {SAVE_DIR}")
print(f"  - efficientnetb1_beans_distilled_quantized.tflite")
print("\n" + "="*80)
# Out:
# ================================================================================
# QUANTIZATION SUMMARY
# ================================================================================
#
# ✓ FP32 baseline loaded and evaluated
#   - Accuracy: 0.9638
#   - Model size: 39.18 MB
#
# ✓  quantization completed
#   - Accuracy: 0.8292
#   - Accuracy drop: 13.46%
#   - Model size: 8.16 MB
#   - Size reduction: 79.18%
#   - Latency improvement: 66.24%
#
# ✓ Results saved to: c:\Users\k nithin\Downloads\M.Tech Project\results\quantization
#   - CSV: efficientnetb1_kd_quantization_comparison.csv
#   - Plots: confusion_matrices, accuracy_comparison, size_latency
#
# ✓ Models saved to: c:\Users\k nithin\Downloads\M.Tech Project\models
#   - efficientnetb1_beans_distilled_quantized.tflite
#
# ================================================================================

# %% [markdown]
# ## Code
