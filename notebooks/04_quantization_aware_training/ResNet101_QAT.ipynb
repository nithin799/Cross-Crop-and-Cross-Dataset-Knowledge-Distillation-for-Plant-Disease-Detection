# %% [markdown]
# # ResNet101 KD Quantization: Direct Quantization of Saved Student Model
#
# This notebook loads the saved ResNet101 student trained via knowledge distillation and applies post-training quantization without retraining. We compare:
# - FP32 KD student baseline
# - TFLite quantized model
#
# Metrics: accuracy, model size, inference latency.

# %% [markdown]
# ## Data Loading and Preprocessing
#
# Loading the dataset and applying preprocessing (normalization, augmentation, etc.).

# %%
import os
import time
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

print(f"TensorFlow version: {tf.__version__}")

current_dir = os.getcwd()
project_root = current_dir
while not (os.path.exists(os.path.join(project_root, 'Beans dataset')) and 
           os.path.exists(os.path.join(project_root, 'models'))):
    project_root = os.path.dirname(project_root)
    if project_root == os.path.dirname(project_root):
        raise RuntimeError("Could not find project root")

print(f"Project root: {project_root}")

DATA_DIR = os.path.join(project_root, "Beans dataset")
SAVE_DIR = os.path.join(project_root, "models")
RESULTS_DIR = os.path.join(project_root, "results", "quantization")
os.makedirs(RESULTS_DIR, exist_ok=True)

IMG_SIZE = (224, 224)
BATCH_SIZE = 8
SEED = 42
NUM_CLASSES = 3

train_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    labels="inferred",
    label_mode="int",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=SEED,
    validation_split=0.3,
    subset="training"
)
class_names = train_ds.class_names

val_test_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    labels="inferred",
    label_mode="int",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=SEED,
    validation_split=0.3,
    subset="validation"
)

val_batches = tf.data.experimental.cardinality(val_test_ds).numpy()
test_ds = val_test_ds.take(val_batches // 2)
val_ds = val_test_ds.skip(val_batches // 2)

train_ds = train_ds.map(lambda x, y: (tf.keras.applications.resnet.preprocess_input(x), y))
val_ds = val_ds.map(lambda x, y: (tf.keras.applications.resnet.preprocess_input(x), y))
test_ds = test_ds.map(lambda x, y: (tf.keras.applications.resnet.preprocess_input(x), y))

train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.prefetch(tf.data.AUTOTUNE)
test_ds = test_ds.prefetch(tf.data.AUTOTUNE)

print("Class order:", class_names)
print(f"Train batches: {len(train_ds)}")
print(f"Val batches: {len(val_ds)}")
print(f"Test batches: {len(test_ds)}")
# Out:
# TensorFlow version: 2.21.0
# Project root: c:\Users\k nithin\Downloads\M.Tech Project
# Found 59069 files belonging to 3 classes.
# Using 41349 files for training.
# Found 59069 files belonging to 3 classes.
# Using 17720 files for validation.
# Class order: ['anthra', 'healthy', 'rust']
# Train batches: 5169
# Val batches: 1108
# Test batches: 1107

# %% [markdown]
# ## Step 2: Load Saved KD Student & Build Inference Model

# %%
kd_student_path = os.path.join(SAVE_DIR, "resnet101_beans_distilled.keras")
print(f"Loading KD student from: {kd_student_path}")

source_student_model = tf.keras.models.load_model(kd_student_path, compile=False)
print(f"Loaded source model type: {type(source_student_model)}")
print(f"Source model outputs: {source_student_model.output_names}")

inference_model = tf.keras.Model(
    inputs=source_student_model.input,
    outputs=source_student_model.get_layer("bean_logits").output,
    name="resnet101_beans_logits_only"
)

print("\nInference model created")
print(f"Input shape: {inference_model.input_shape}")
print(f"Output shape: {inference_model.output_shape}")
print(f"Inference model class: {inference_model.__class__.__module__}.{inference_model.__class__.__name__}")
# Out:
# Loading KD student from: c:\Users\k nithin\Downloads\M.Tech Project\models\resnet101_beans_distilled.keras
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Loaded source model type: <class 'keras.src.models.functional.Functional'>
# Source model outputs: ListWrapper(['conv4_block23_out', 'conv5_block3_out', 'bean_logits'])
#
# Inference model created
# Input shape: (None, 224, 224, 3)
# Output shape: (None, 3)
# Inference model class: keras.src.models.functional.Functional

# %% [markdown]
# ## Step 3: Evaluate FP32 Baseline (Before Quantization)

# %%
def evaluate_model(model, test_dataset, model_name="Model"):
    """Evaluate Keras model on test set and return metrics."""
    y_true = []
    y_pred = []
    y_prob = []
    total_elapsed = 0.0
    total_images = 0

    for images, labels in test_dataset:
        start = time.perf_counter()
        outputs = model(images, training=False)
        elapsed = time.perf_counter() - start

        logits = outputs["logits"] if isinstance(outputs, dict) else outputs
        probs = tf.nn.softmax(logits)

        probs_np = probs.numpy()
        labels_np = labels.numpy()

        y_prob.extend(probs_np)
        y_pred.extend(np.argmax(probs_np, axis=1))
        y_true.extend(labels_np)

        total_elapsed += elapsed
        total_images += int(images.shape[0])

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    y_prob = np.array(y_prob)

    accuracy = accuracy_score(y_true, y_pred)
    avg_latency = total_elapsed / total_images if total_images else 0.0

    num_params = model.count_params() if hasattr(model, "count_params") else 0
    cm = confusion_matrix(y_true, y_pred)
    report = classification_report(y_true, y_pred, target_names=class_names, output_dict=True)

    print(f"\n{model_name} Evaluation:")
    print(f"  Accuracy: {accuracy:.4f}")
    print(f"  Avg Latency (per image): {avg_latency * 1000:.2f} ms")
    print(f"  Parameters: {num_params:,}")
    print(f"\nClassification Report:\n{classification_report(y_true, y_pred, target_names=class_names)}")

    return {
        'accuracy': accuracy,
        'latency_ms': avg_latency * 1000,
        'num_params': num_params,
        'y_true': y_true,
        'y_pred': y_pred,
        'y_prob': y_prob,
        'cm': cm,
        'report': report
    }

fp32_metrics = evaluate_model(inference_model, test_ds, "FP32 KD Student (Baseline)")
# Out:
# FP32 KD Student (Baseline) Evaluation:
#   Accuracy: 0.9886
#   Avg Latency (per image): 164.40 ms
#   Parameters: 43,708,803
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       anthra       0.99      0.99      0.99      2031
#      healthy       0.98      1.00      0.99      3794
#         rust       1.00      0.97      0.99      3031
#
#     accuracy                           0.99      8856
#    macro avg       0.99      0.99      0.99      8856
# weighted avg       0.99      0.99      0.99      8856

# %% [markdown]
# ## Step 4: Convert Saved Student to TFLite

# %%
def evaluate_tflite(tflite_model_path, test_dataset, model_name="TFLite Model"):
    """Evaluate TFLite model using interpreter."""
    interpreter = tf.lite.Interpreter(model_path=tflite_model_path)
    interpreter.allocate_tensors()

    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()

    print(f"Input details: {input_details[0]['shape']}, dtype: {input_details[0]['dtype']}")
    print(f"Output details: {output_details[0]['shape']}, dtype: {output_details[0]['dtype']}")

    input_scale, input_zero_point = input_details[0]['quantization']
    output_scale, output_zero_point = output_details[0]['quantization']
    if input_scale == 0:
        input_scale = 1.0
    if output_scale == 0:
        output_scale = 1.0

    y_true = []
    y_pred = []
    y_prob = []
    total_elapsed = 0.0
    total_images = 0

    for images, labels in test_dataset:
        batch_size = int(images.shape[0])

        interpreter.resize_tensor_input(input_details[0]['index'], [batch_size, 224, 224, 3])
        interpreter.allocate_tensors()

        if input_details[0]['dtype'] == np.int8:
            input_data = np.round(images.numpy() / input_scale + input_zero_point).astype(np.int8)
        elif input_details[0]['dtype'] == np.uint8:
            input_data = np.round(images.numpy() / input_scale + input_zero_point).astype(np.uint8)
        else:
            input_data = images.numpy().astype(input_details[0]['dtype'])

        interpreter.set_tensor(input_details[0]['index'], input_data)

        start = time.perf_counter()
        interpreter.invoke()
        elapsed = time.perf_counter() - start
        total_elapsed += elapsed
        total_images += batch_size

        output_data = interpreter.get_tensor(output_details[0]['index'])

        if output_details[0]['dtype'] in (np.int8, np.uint8):
            logits = (output_data.astype(np.float32) - output_zero_point) * output_scale
        else:
            logits = output_data.astype(np.float32)

        probs = tf.nn.softmax(logits)
        probs_np = probs.numpy()
        y_prob.extend(probs_np)
        y_pred.extend(np.argmax(probs_np, axis=1))
        y_true.extend(labels.numpy())

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    y_prob = np.array(y_prob)

    accuracy = accuracy_score(y_true, y_pred)
    avg_latency = total_elapsed / total_images if total_images else 0.0
    model_size_kb = os.path.getsize(tflite_model_path) / 1024
    cm = confusion_matrix(y_true, y_pred)

    print(f"\n{model_name} Evaluation:")
    print(f"  Accuracy: {accuracy:.4f}")
    print(f"  Avg Latency (per image): {avg_latency * 1000:.2f} ms")
    print(f"  Model Size: {model_size_kb:.2f} KB")
    print(f"\nClassification Report:\n{classification_report(y_true, y_pred, target_names=class_names)}")

    return {
        'accuracy': accuracy,
        'latency_ms': avg_latency * 1000,
        'model_size_kb': model_size_kb,
        'y_true': y_true,
        'y_pred': y_pred,
        'y_prob': y_prob,
        'cm': cm
    }

converter = tf.lite.TFLiteConverter.from_keras_model(inference_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]

def representative_data_gen():
    """Generate representative data for quantization."""
    count = 0
    for images, _ in train_ds:
        yield [tf.cast(images, tf.float32).numpy()]
        count += 1
        if count >= 10:
            break

converter.representative_dataset = representative_data_gen
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

print("Converting to TFLite...")
tflite_quantized_model = converter.convert()
print(f"Conversion complete. Model size: {len(tflite_quantized_model) / 1024:.2f} KB")

tflite_path = os.path.join(SAVE_DIR, "resnet101_beans_distilled_quantized.tflite")
with open(tflite_path, 'wb') as f:
    f.write(tflite_quantized_model)

print(f"TFLite model saved to: {tflite_path}")
# Out:
# Converting to TFLite...
# INFO:tensorflow:Assets written to: C:\Users\KNITHI~1\AppData\Local\Temp\tmpi14cv8w5\assets
# INFO:tensorflow:Assets written to: C:\Users\KNITHI~1\AppData\Local\Temp\tmpi14cv8w5\assets
# Saved artifact at 'C:\Users\KNITHI~1\AppData\Local\Temp\tmpi14cv8w5'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   2023502656464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023502759888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023502768160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023502770272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023502763584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023502765872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023502764816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513789136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513785616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513791776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513786496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513788960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513797232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513795296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513784912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513799872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513794592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513797056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513857488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513855200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513799168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513854672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513851680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513860128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513854848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513857312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513851152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513864000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513861712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513862768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513863296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513969360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513965840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513972000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513966720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513969184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513977456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513975520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513965136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513980096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513974816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513977280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513979392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514018512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514014992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514021152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514015872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514018336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514028192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514026256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514027312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514029776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514025552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514028016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514118400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514116464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514114176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514120864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023502767984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514115760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514126320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514124384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514125440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514127904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514123680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514126144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514218112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514216176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514213888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514220752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514215472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514217936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514224272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514224976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514226032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514292640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514293344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514292464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514302848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514300560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514300032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514298096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514296688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514305488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514300208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514302672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514306544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514304080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514307072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514308128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514382128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514380192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514377904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514384768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514379488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514381952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514388288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514388992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514457360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514457536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514456656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514456480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514464048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514462112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514460704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514466688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514461408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514463872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514471792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514465984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514554432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514558480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514556016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514555664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514563936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514562000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514555488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514566576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514561296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514563760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514570096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514565872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514619968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514624016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514621552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514621200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514631056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514629120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514622432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514633696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514628416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514630880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514632992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514721264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514722672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514723904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514718624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514721088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514729360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514727424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514719504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514732000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514726720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514729184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514731296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514821152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514817632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514823792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514818512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514820976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514829248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514827312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514816928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514831888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514826608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514829072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511743776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511741488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023514831184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511740960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511737968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511746416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511741136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511743600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511737440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511750288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511748000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511749056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511749584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511823056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511819536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511825696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511820416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511822880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511831152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511829216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511818832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511833792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511828512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511830976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511833088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511921360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511917840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511924000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511918720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511921184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511931040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511929104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511930160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511932624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511928400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023511930864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512004864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512002928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512000640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512007504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512002224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512004688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512012960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512011024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512012080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512014544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512010320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512012784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512088368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512086432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512084144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512091008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512085728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512088192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512094528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512095232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512178752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512179104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512178928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512179984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512186672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512184736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512183328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512189312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512184032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512186496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512194416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512188608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512227904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512231952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512229488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512229136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512237408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512235472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512228960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512240048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512234768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512237232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512243568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512239344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512326208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512330256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512327792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512327440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512337296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512335360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512328672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512339936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512334656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512337120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512339232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512427504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512428912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512430144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512424864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512427328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512435600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512433664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512425744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512438240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512432960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512435424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512437536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512494624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512491104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512497264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512491984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512494448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512502720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512500784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512490400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512505360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512500080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512502544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512504656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512609312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512605792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512611952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512606672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512609136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512618992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512617056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512618112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512620576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512616352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512618816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512692816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512690880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512688592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512695456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512690176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512692640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512700912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512698976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512700032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512702496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512698272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512700736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512743552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512741616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512739328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512746192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512740912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512743376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512749712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512750416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512751472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512850848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512851552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512850672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512858240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512856304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512854896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512860880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512855600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512858064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512865984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512860176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512933648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512936288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512933824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512933472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512941744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512939808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512933296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512944384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512939104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512941568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512947904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512943680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512999184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513001824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512999360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023512999008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513008864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513006928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513000240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513011504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513006224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513008688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513010800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513100656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513100480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513101712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513099248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513098896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513107168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513105232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513097136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513109808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513104528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513106992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513109104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513198960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513195440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513201600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513196320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513198784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513207056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513205120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513194736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513209696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513204416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513206880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513208992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513248112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513244592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513250752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513245472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513247936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513257792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513255856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513256912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513259376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513255152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513257616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513348000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513342544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513343776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513350640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513345360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513347824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513356096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513354160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513355216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513357680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513353456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513355920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513464272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513457232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513460048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513466912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513461632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513464096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513470432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513471136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513472016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513522240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513472368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513523120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513529808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513527872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513526464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513532448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513527168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513529632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513537552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513538256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513621072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513624240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513621952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513623008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513629696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513627760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513622128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513632336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513627056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513629520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513635856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513636560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513672336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513673392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513670928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513670576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513680432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513678496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513671808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513683072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513677792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513680256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023513682368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023689883840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023689883664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023689884896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023689882432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023689882080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023689890352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023689888416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023689880320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023689892992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023689887712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023689890176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023689892288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023689949376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023689945856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023689952016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023689946736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023689949200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023689957472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023689955536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023689945152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023689960112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023689954832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023689957296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023689959408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690031296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690027776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690033936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690028656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690031120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690040976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690039040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690031472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690042560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690038336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690040800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690131184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690125728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690126960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690133824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690128544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690131008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690139280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690137344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690127840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690140864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690136640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690139104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690214688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690207648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690210464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690217328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690212048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690214512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690220848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690221552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690222432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690273008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690222080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690273360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690280224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690278288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690276880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690282864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690277584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690280048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690287968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690288672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690355104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690358272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690355808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690355456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690363728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690361792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690354928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690366368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690361088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690363552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690369888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690370592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690437024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690440192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690437728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690437376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690447232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690445296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690439664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690449872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690444592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690447056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690449168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690555408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690552416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690556464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690554000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690553648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690561920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690559984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690551888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690564560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690559280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690561744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690563856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690637328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690638032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690639968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690634688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690637152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690645424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690643488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690637504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690648064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690642784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690645248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690647360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690702864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690703568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690705504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690700224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690702688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690712544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690710608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690700576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690714128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690709904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690712368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690786368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690780912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690782848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690789008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690783728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690786192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690794464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690792528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690782144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690796048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690791824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690794288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690919024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690911984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690915504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690921664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690916384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690918848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690927824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690925360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690924480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690927120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690926944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690961312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690970992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690968704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690968176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690966240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690964832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690973632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690968352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690970816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690962896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690972224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690975216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023690976272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691083040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691076000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691078816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691085680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691080400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691082864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691089200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691089904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691090784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691141360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691090432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691141712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691148576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691146640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691145232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691151216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691145936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691148400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691156320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691157024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691223456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691226624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691224336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691225392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691232080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691230144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691225216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691234720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691229440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691231904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691238240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691238944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691305376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691308544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691306080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691305728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691315408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691314880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691316464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2023691317344: TensorSpec(shape=(), dtype=tf.resource, name=None)
# c:\Users\k nithin\Downloads\M.Tech Project\.venv\lib\site-packages\tensorflow\lite\python\convert.py:846: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Conversion complete. Model size: 44036.42 KB
# TFLite model saved to: c:\Users\k nithin\Downloads\M.Tech Project\models\resnet101_beans_distilled_quantized.tflite

# %% [markdown]
# ## Step 5: Evaluate TFLite Model

# %%
tflite_metrics = evaluate_tflite(tflite_path, test_ds, "TFLite Quantized Model")
# Out:
# Input details: [  1 224 224   3], dtype: <class 'numpy.int8'>
# Output details: [1 3], dtype: <class 'numpy.int8'>
# c:\Users\k nithin\Downloads\M.Tech Project\.venv\lib\site-packages\tensorflow\lite\python\interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# TFLite Quantized Model Evaluation:
#   Accuracy: 0.9748
#   Avg Latency (per image): 194.68 ms
#   Model Size: 44036.42 KB
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       anthra       0.99      0.99      0.99      2035
#      healthy       0.98      0.96      0.97      3788
#         rust       0.95      0.98      0.97      3033
#
#     accuracy                           0.97      8856
#    macro avg       0.98      0.98      0.98      8856
# weighted avg       0.98      0.97      0.97      8856

# %% [markdown]
# ## Step 6: Comparison - FP32 vs QAT vs TFLite

# %%
fp32_model_size_kb = os.path.getsize(kd_student_path) / 1024
quantized_model_size_kb = os.path.getsize(tflite_path) / 1024

comparison_df = pd.DataFrame({
    'Model': ['FP32 KD Student', 'INT8 Quantized'],
    'Accuracy': [
        fp32_metrics['accuracy'],
        tflite_metrics['accuracy']
    ],
    'Latency (ms)': [
        fp32_metrics['latency_ms'],
        tflite_metrics['latency_ms']
    ],
    'Model Size (KB)': [
        fp32_model_size_kb,
        quantized_model_size_kb
    ]
})

print("\n" + "="*80)
print("COMPARISON: FP32 vs INT8 Quantized")
print("="*80)
print(comparison_df.to_string(index=False))
print("="*80)

accuracy_drop = (fp32_metrics['accuracy'] - tflite_metrics['accuracy']) * 100
size_reduction = ((fp32_model_size_kb - quantized_model_size_kb) / fp32_model_size_kb) * 100
latency_improvement = ((fp32_metrics['latency_ms'] - tflite_metrics['latency_ms']) / fp32_metrics['latency_ms']) * 100 if fp32_metrics['latency_ms'] else 0.0

print(f"\nMetrics:")
print(f"  Accuracy drop (FP32 → TFLite): {accuracy_drop:.2f}%")
print(f"  Model size reduction: {size_reduction:.2f}%")
print(f"  Latency improvement: {latency_improvement:.2f}%")

comparison_csv_path = os.path.join(RESULTS_DIR, "resnet101_kd_quantization_comparison.csv")
comparison_df.to_csv(comparison_csv_path, index=False)
print(f"\nComparison saved to: {comparison_csv_path}")
# Out:
# ================================================================================
# COMPARISON: FP32 vs INT8 Quantized
# ================================================================================
#           Model  Accuracy  Latency (ms)  Model Size (KB)
# FP32 KD Student  0.988595    164.395861    171976.371094
#  INT8 Quantized  0.974819    194.677755     44036.421875
# ================================================================================
#
# Metrics:
#   Accuracy drop (FP32 → TFLite): 1.38%
#   Model size reduction: 74.39%
#   Latency improvement: -18.42%
#
# Comparison saved to: c:\Users\k nithin\Downloads\M.Tech Project\results\quantization\resnet101_kd_quantization_comparison.csv

# %% [markdown]
# ## Step 7: Visualizations

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

for idx, (cm, title) in enumerate([
    (fp32_metrics['cm'], 'FP32 KD Student'),
    (tflite_metrics['cm'], 'INT8 Quantized')
]):
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[idx],
                xticklabels=class_names, yticklabels=class_names)
    axes[idx].set_title(title)
    axes[idx].set_xlabel('Predicted')
    axes[idx].set_ylabel('True')

plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "resnet101_kd_quantization_confusion_matrices.png"), dpi=150, bbox_inches='tight')
plt.show()

print(f"Confusion matrices saved")
# Out:
# Confusion matrices saved

# %%
fig, ax = plt.subplots(figsize=(7, 5))

models = ['FP32\nBaseline', 'INT8\nQuantized']
accuracies = [
    fp32_metrics['accuracy'],
    tflite_metrics['accuracy']
]

bars = ax.bar(models, accuracies, color=['#1f77b4', '#2ca02c'], alpha=0.7, edgecolor='black')
ax.set_ylabel('Accuracy', fontsize=12)
ax.set_title('Accuracy Comparison: FP32 vs INT8 Quantized', fontsize=14, fontweight='bold')
ax.set_ylim([min(accuracies) - 0.05, 1.05])
ax.grid(axis='y', alpha=0.3)

for bar, acc in zip(bars, accuracies):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2., height,
            f'{acc:.4f}',
            ha='center', va='bottom', fontsize=11, fontweight='bold')

plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "resnet101_kd_quantization_accuracy_comparison.png"), dpi=150, bbox_inches='tight')
plt.show()

print(f"Accuracy comparison plot saved")
# Out:
# Accuracy comparison plot saved

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 5))

models = ['FP32\nBaseline', 'INT8\nQuantized']
sizes = [
    fp32_model_size_kb / 1024,
    quantized_model_size_kb / 1024
]
latencies = [
    fp32_metrics['latency_ms'],
    tflite_metrics['latency_ms']
]

bars1 = ax1.bar(models, sizes, color=['#1f77b4', '#2ca02c'], alpha=0.7, edgecolor='black')
ax1.set_ylabel('Model Size (MB)', fontsize=12)
ax1.set_title('Model Size Comparison', fontsize=13, fontweight='bold')
ax1.grid(axis='y', alpha=0.3)

for bar, size in zip(bars1, sizes):
    height = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2., height,
            f'{size:.2f}',
            ha='center', va='bottom', fontsize=10, fontweight='bold')

bars2 = ax2.bar(models, latencies, color=['#1f77b4', '#2ca02c'], alpha=0.7, edgecolor='black')
ax2.set_ylabel('Latency (ms)', fontsize=12)
ax2.set_title('Inference Latency (per image)', fontsize=13, fontweight='bold')
ax2.grid(axis='y', alpha=0.3)

for bar, lat in zip(bars2, latencies):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height,
            f'{lat:.2f}',
            ha='center', va='bottom', fontsize=10, fontweight='bold')

plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "resnet101_kd_quantization_size_latency.png"), dpi=150, bbox_inches='tight')
plt.show()

print(f"Size and latency comparison plots saved")
# Out:
# Size and latency comparison plots saved

# %% [markdown]
# ## Summary

# %%
print("\n" + "="*80)
print("QUANTIZATION SUMMARY")
print("="*80)
print(f"\n✓ FP32 baseline loaded and evaluated")
print(f"  - Accuracy: {fp32_metrics['accuracy']:.4f}")
print(f"  - Model size: {fp32_model_size_kb / 1024:.2f} MB")

print(f"\n✓ TFLite quantization completed")
print(f"  - Accuracy: {tflite_metrics['accuracy']:.4f}")
print(f"  - Accuracy drop: {(fp32_metrics['accuracy'] - tflite_metrics['accuracy']) * 100:.2f}%")
print(f"  - Model size: {quantized_model_size_kb / 1024:.2f} MB")
print(f"  - Size reduction: {size_reduction:.2f}%")
print(f"  - Latency improvement: {latency_improvement:.2f}%")

print(f"\n✓ Results saved to: {RESULTS_DIR}")
print(f"  - CSV: resnet101_kd_quantization_comparison.csv")
print(f"  - Plots: confusion_matrices, accuracy_comparison, size_latency")
print(f"\n✓ Models saved to: {SAVE_DIR}")
print(f"  - resnet101_beans_distilled_quantized.tflite")
print("\n" + "="*80)
# Out:
# ================================================================================
# QUANTIZATION SUMMARY
# ================================================================================
#
# ✓ FP32 baseline loaded and evaluated
#   - Accuracy: 0.9886
#   - Model size: 167.95 MB
#
# ✓ TFLite quantization completed
#   - Accuracy: 0.9748
#   - Accuracy drop: 1.38%
#   - Model size: 43.00 MB
#   - Size reduction: 74.39%
#   - Latency improvement: -18.42%
#
# ✓ Results saved to: c:\Users\k nithin\Downloads\M.Tech Project\results\quantization
#   - CSV: resnet101_kd_quantization_comparison.csv
#   - Plots: confusion_matrices, accuracy_comparison, size_latency
#
# ✓ Models saved to: c:\Users\k nithin\Downloads\M.Tech Project\models
#   - resnet101_beans_distilled_quantized.tflite
#
# ================================================================================

# %% [markdown]
# ## Code
