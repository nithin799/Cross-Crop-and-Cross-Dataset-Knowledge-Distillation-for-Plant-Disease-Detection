# %% [markdown]
# # Xception KD Quantization: Direct Quantization of Saved Student Model
#
# This notebook loads the saved Xception student trained via knowledge distillation and applies post-training quantization without retraining. We compare:
# - FP32 KD student baseline
# - TFLite quantized model
#
# Metrics: accuracy, model size, inference latency.

# %% [markdown]
# ## Step 1: Setup & Imports

# %%
import os
import time
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

print(f"TensorFlow version: {tf.__version__}")

current_dir = os.getcwd()
project_root = current_dir
while not (os.path.exists(os.path.join(project_root, 'Beans dataset')) and 
           os.path.exists(os.path.join(project_root, 'models'))):
    project_root = os.path.dirname(project_root)
    if project_root == os.path.dirname(project_root):
        raise RuntimeError("Could not find project root")

print(f"Project root: {project_root}")

DATA_DIR = os.path.join(project_root, "Beans dataset")
SAVE_DIR = os.path.join(project_root, "models")
RESULTS_DIR = os.path.join(project_root, "results", "quantization")
os.makedirs(RESULTS_DIR, exist_ok=True)

IMG_SIZE = (224, 224)
BATCH_SIZE = 8
SEED = 42
NUM_CLASSES = 3

train_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    labels="inferred",
    label_mode="int",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=SEED,
    validation_split=0.3,
    subset="training"
)
class_names = train_ds.class_names

val_test_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    labels="inferred",
    label_mode="int",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=SEED,
    validation_split=0.3,
    subset="validation"
)

val_batches = tf.data.experimental.cardinality(val_test_ds).numpy()
test_ds = val_test_ds.take(val_batches // 2)
val_ds = val_test_ds.skip(val_batches // 2)

train_ds = train_ds.map(lambda x, y: (tf.keras.applications.resnet.preprocess_input(x), y))
val_ds = val_ds.map(lambda x, y: (tf.keras.applications.resnet.preprocess_input(x), y))
test_ds = test_ds.map(lambda x, y: (tf.keras.applications.resnet.preprocess_input(x), y))

train_ds = train_ds.prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.prefetch(tf.data.AUTOTUNE)
test_ds = test_ds.prefetch(tf.data.AUTOTUNE)

print("Class order:", class_names)
print(f"Train batches: {len(train_ds)}")
print(f"Val batches: {len(val_ds)}")
print(f"Test batches: {len(test_ds)}")
# Out:
# TensorFlow version: 2.21.0
# Project root: c:\Users\k nithin\Downloads\M.Tech Project
# Found 59069 files belonging to 3 classes.
# Using 41349 files for training.
# Found 59069 files belonging to 3 classes.
# Using 17720 files for validation.
# Class order: ['anthra', 'healthy', 'rust']
# Train batches: 5169
# Val batches: 1108
# Test batches: 1107

# %% [markdown]
# ## Step 2: Load Saved KD Student & Build Inference Model

# %%
kd_student_path = os.path.join(SAVE_DIR, "xception_beans_distilled.keras")
print(f"Loading KD student from: {kd_student_path}")

source_student_model = tf.keras.models.load_model(kd_student_path, compile=False)
print(f"Loaded source model type: {type(source_student_model)}")
print(f"Source model outputs: {source_student_model.output_names}")

inference_model = tf.keras.Model(
    inputs=source_student_model.input,
    outputs=source_student_model.get_layer("bean_logits").output,
    name="xception_beans_logits_only"
)

print("\nInference model created")
print(f"Input shape: {inference_model.input_shape}")
print(f"Output shape: {inference_model.output_shape}")
print(f"Inference model class: {inference_model.__class__.__module__}.{inference_model.__class__.__name__}")
# Out:
# Loading KD student from: c:\Users\k nithin\Downloads\M.Tech Project\models\xception_beans_distilled.keras
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Loaded source model type: <class 'keras.src.models.functional.Functional'>
# Source model outputs: ListWrapper(['proj_0', 'proj_1', 'bean_logits'])
#
# Inference model created
# Input shape: (None, 224, 224, 3)
# Output shape: (None, 3)
# Inference model class: keras.src.models.functional.Functional

# %% [markdown]
# ## Step 3: Evaluate FP32 Baseline (Before Quantization)

# %%
def evaluate_model(model, test_dataset, model_name="Model"):
    """Evaluate Keras model on test set and return metrics."""
    y_true = []
    y_pred = []
    y_prob = []
    total_elapsed = 0.0
    total_images = 0

    for images, labels in test_dataset:
        start = time.perf_counter()
        outputs = model(images, training=False)
        elapsed = time.perf_counter() - start

        logits = outputs["logits"] if isinstance(outputs, dict) else outputs
        probs = tf.nn.softmax(logits)

        probs_np = probs.numpy()
        labels_np = labels.numpy()

        y_prob.extend(probs_np)
        y_pred.extend(np.argmax(probs_np, axis=1))
        y_true.extend(labels_np)

        total_elapsed += elapsed
        total_images += int(images.shape[0])

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    y_prob = np.array(y_prob)

    accuracy = accuracy_score(y_true, y_pred)
    avg_latency = total_elapsed / total_images if total_images else 0.0

    num_params = model.count_params() if hasattr(model, "count_params") else 0
    cm = confusion_matrix(y_true, y_pred)
    report = classification_report(y_true, y_pred, target_names=class_names, output_dict=True)

    print(f"\n{model_name} Evaluation:")
    print(f"  Accuracy: {accuracy:.4f}")
    print(f"  Avg Latency (per image): {avg_latency * 1000:.2f} ms")
    print(f"  Parameters: {num_params:,}")
    print(f"\nClassification Report:\n{classification_report(y_true, y_pred, target_names=class_names)}")

    return {
        'accuracy': accuracy,
        'latency_ms': avg_latency * 1000,
        'num_params': num_params,
        'y_true': y_true,
        'y_pred': y_pred,
        'y_prob': y_prob,
        'cm': cm,
        'report': report
    }

fp32_metrics = evaluate_model(inference_model, test_ds, "FP32 KD Student (Baseline)")
# Out:
# FP32 KD Student (Baseline) Evaluation:
#   Accuracy: 0.9464
#   Avg Latency (per image): 76.72 ms
#   Parameters: 20,869,691
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       anthra       0.96      0.99      0.98      2031
#      healthy       0.91      1.00      0.95      3794
#         rust       1.00      0.85      0.92      3031
#
#     accuracy                           0.95      8856
#    macro avg       0.96      0.95      0.95      8856
# weighted avg       0.95      0.95      0.95      8856

# %% [markdown]
# ## Step 4: Convert Saved Student to TFLite

# %%
def evaluate_tflite(tflite_model_path, test_dataset, model_name="TFLite Model"):
    """Evaluate TFLite model using interpreter."""
    interpreter = tf.lite.Interpreter(model_path=tflite_model_path)
    interpreter.allocate_tensors()

    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()

    print(f"Input details: {input_details[0]['shape']}, dtype: {input_details[0]['dtype']}")
    print(f"Output details: {output_details[0]['shape']}, dtype: {output_details[0]['dtype']}")

    input_scale, input_zero_point = input_details[0]['quantization']
    output_scale, output_zero_point = output_details[0]['quantization']
    if input_scale == 0:
        input_scale = 1.0
    if output_scale == 0:
        output_scale = 1.0

    y_true = []
    y_pred = []
    y_prob = []
    total_elapsed = 0.0
    total_images = 0

    for images, labels in test_dataset:
        batch_size = int(images.shape[0])

        interpreter.resize_tensor_input(input_details[0]['index'], [batch_size, 224, 224, 3])
        interpreter.allocate_tensors()

        if input_details[0]['dtype'] == np.int8:
            input_data = np.round(images.numpy() / input_scale + input_zero_point).astype(np.int8)
        elif input_details[0]['dtype'] == np.uint8:
            input_data = np.round(images.numpy() / input_scale + input_zero_point).astype(np.uint8)
        else:
            input_data = images.numpy().astype(input_details[0]['dtype'])

        interpreter.set_tensor(input_details[0]['index'], input_data)

        start = time.perf_counter()
        interpreter.invoke()
        elapsed = time.perf_counter() - start
        total_elapsed += elapsed
        total_images += batch_size

        output_data = interpreter.get_tensor(output_details[0]['index'])

        if output_details[0]['dtype'] in (np.int8, np.uint8):
            logits = (output_data.astype(np.float32) - output_zero_point) * output_scale
        else:
            logits = output_data.astype(np.float32)

        probs = tf.nn.softmax(logits)
        probs_np = probs.numpy()
        y_prob.extend(probs_np)
        y_pred.extend(np.argmax(probs_np, axis=1))
        y_true.extend(labels.numpy())

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    y_prob = np.array(y_prob)

    accuracy = accuracy_score(y_true, y_pred)
    avg_latency = total_elapsed / total_images if total_images else 0.0
    model_size_kb = os.path.getsize(tflite_model_path) / 1024
    cm = confusion_matrix(y_true, y_pred)

    print(f"\n{model_name} Evaluation:")
    print(f"  Accuracy: {accuracy:.4f}")
    print(f"  Avg Latency (per image): {avg_latency * 1000:.2f} ms")
    print(f"  Model Size: {model_size_kb:.2f} KB")
    print(f"\nClassification Report:\n{classification_report(y_true, y_pred, target_names=class_names)}")

    return {
        'accuracy': accuracy,
        'latency_ms': avg_latency * 1000,
        'model_size_kb': model_size_kb,
        'y_true': y_true,
        'y_pred': y_pred,
        'y_prob': y_prob,
        'cm': cm
    }
converter = tf.lite.TFLiteConverter.from_keras_model(inference_model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]

def representative_data_gen():
    """Generate representative data for quantization."""
    count = 0
    for images, _ in train_ds:
        yield [tf.cast(images, tf.float32).numpy()]
        count += 1
        if count >= 10:
            break

converter.representative_dataset = representative_data_gen
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

print("Converting to TFLite...")
tflite_quantized_model = converter.convert()
print(f"Conversion complete. Model size: {len(tflite_quantized_model) / 1024:.2f} KB")

tflite_path = os.path.join(SAVE_DIR, "xception_beans_distilled_quantized.tflite")
with open(tflite_path, 'wb') as f:
    f.write(tflite_quantized_model)

print(f"TFLite model saved to: {tflite_path}")
# Out:
# Converting to TFLite...
# INFO:tensorflow:Assets written to: C:\Users\KNITHI~1\AppData\Local\Temp\tmprai23d1j\assets
# INFO:tensorflow:Assets written to: C:\Users\KNITHI~1\AppData\Local\Temp\tmprai23d1j\assets
# Saved artifact at 'C:\Users\KNITHI~1\AppData\Local\Temp\tmprai23d1j'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   1358196172480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196282240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196284352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196277664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196279952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196291920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196290864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196288752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196292272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196292800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196290688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196313248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196310256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196318176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196317120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196317472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196321168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196322224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196396048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196310608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196321696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196325216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196325568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196395872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196399216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196397280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196397984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196403616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196404672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196403088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196404144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196406960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196407136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196510208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196511264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196519360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196509504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196515312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196514256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196514608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196520416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196522704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196520592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196521472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196519888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196577680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196575920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196581728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196580672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196581024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196584720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196579968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196643216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196587360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196585248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196588064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196638640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196644272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196646560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196644448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196645328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196651840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196652720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196651136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358195672864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358196653776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358195671104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358195676384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358195677440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358195673392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358195681488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358195680432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358195680784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358195685184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358195686064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358195684480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358198818592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358195687120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358198816832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358198823696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358198824752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358198819120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358198828800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358198827744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358198828096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358198832496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358198831792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358198885008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358198886240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358198882720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358198883600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358198889232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358198890288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358198885184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358198894336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358198893280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358198893632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358198892576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358198897152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199000576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199002512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358198998992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199001808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199005504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199006560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358198997936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199010608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199009552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199009904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199008848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199013072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199115968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199117200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199113680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199116496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199121776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199122832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199112624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199126880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199125824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199126176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199125120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199147504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199145744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199151552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199150496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199150848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199154544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199155600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199146976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199159648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199158592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199158944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199157888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199247392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199245632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199251440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199250384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199250736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199254432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199255488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199253904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199254960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199257776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199257952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199344640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199345696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199343936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199349744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199348688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199349040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199355024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199355904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199354320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199408416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199355200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199407184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199411760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199412816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199408768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199416864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199415808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199416160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199420560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199421440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199419856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199473952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199420736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199472720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199478880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199479936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199474304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199483984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199482928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199483280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199487680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199486976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199587584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199590576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199586880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199588112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199593568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199594624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199587408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199598672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199597616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199597968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199596912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358199601488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194659344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194660576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194656528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194657936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194663568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194664624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194656000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194668672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194667616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194667968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194666912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194671136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194723120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194726112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194722064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194723472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194730688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194731744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194721536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194735792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194734736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194735088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194734032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194821952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194830048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194820192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194826000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194824944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194825296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194831104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194833392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194831280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194832160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194830576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194919728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194917440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194923776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194917968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194923072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194926768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194927824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194919200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194931872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194930816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194931168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194928176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194986496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194995472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1358194996176: TensorSpec(shape=(), dtype=tf.resource, name=None)
# c:\Users\k nithin\Downloads\M.Tech Project\.venv\lib\site-packages\tensorflow\lite\python\convert.py:846: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Conversion complete. Model size: 21635.14 KB
# TFLite model saved to: c:\Users\k nithin\Downloads\M.Tech Project\models\xception_beans_distilled_quantized.tflite

# %% [markdown]
# ## Step 5: Evaluate TFLite Model

# %%
tflite_metrics = evaluate_tflite(tflite_path, test_ds, "TFLite Quantized Model")
# Out:
# Input details: [  1 224 224   3], dtype: <class 'numpy.int8'>
# Output details: [1 3], dtype: <class 'numpy.int8'>
# c:\Users\k nithin\Downloads\M.Tech Project\.venv\lib\site-packages\tensorflow\lite\python\interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# TFLite Quantized Model Evaluation:
#   Accuracy: 0.6545
#   Avg Latency (per image): 140.86 ms
#   Model Size: 21635.14 KB
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       anthra       0.43      0.99      0.60      2035
#      healthy       0.90      1.00      0.95      3788
#         rust       0.00      0.00      0.00      3033
#
#     accuracy                           0.65      8856
#    macro avg       0.45      0.66      0.52      8856
# weighted avg       0.49      0.65      0.54      8856
# c:\Users\k nithin\Downloads\M.Tech Project\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\k nithin\Downloads\M.Tech Project\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\k nithin\Downloads\M.Tech Project\.venv\lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# ## Step 6: Comparison - FP32 vs TFLite

# %%
fp32_model_size_kb = os.path.getsize(kd_student_path) / 1024
quantized_model_size_kb = os.path.getsize(tflite_path) / 1024

comparison_df = pd.DataFrame({
    'Model': ['FP32 KD Student', 'INT8 Quantized'],
    'Accuracy': [
        fp32_metrics['accuracy'],
        tflite_metrics['accuracy']
    ],
    'Latency (ms)': [
        fp32_metrics['latency_ms'],
        tflite_metrics['latency_ms']
    ],
    'Model Size (KB)': [
        fp32_model_size_kb,
        quantized_model_size_kb
    ]
})

print("\n" + "="*80)
print("COMPARISON: FP32 vs INT8 Quantized")
print("="*80)
print(comparison_df.to_string(index=False))
print("="*80)

accuracy_drop = (fp32_metrics['accuracy'] - tflite_metrics['accuracy']) * 100
size_reduction = ((fp32_model_size_kb - quantized_model_size_kb) / fp32_model_size_kb) * 100
latency_improvement = ((fp32_metrics['latency_ms'] - tflite_metrics['latency_ms']) / fp32_metrics['latency_ms']) * 100 if fp32_metrics['latency_ms'] else 0.0

print(f"\nMetrics:")
print(f"  Accuracy drop (FP32 → TFLite): {accuracy_drop:.2f}%")
print(f"  Model size reduction: {size_reduction:.2f}%")
print(f"  Latency improvement: {latency_improvement:.2f}%")

comparison_csv_path = os.path.join(RESULTS_DIR, "xception_kd_quantization_comparison.csv")
comparison_df.to_csv(comparison_csv_path, index=False)
print(f"\nComparison saved to: {comparison_csv_path}")
# Out:
# ================================================================================
# COMPARISON: FP32 vs INT8 Quantized
# ================================================================================
#           Model  Accuracy  Latency (ms)  Model Size (KB)
# FP32 KD Student  0.946364     76.723052    101327.153320
#  INT8 Quantized  0.654472    140.861147     21635.140625
# ================================================================================
#
# Metrics:
#   Accuracy drop (FP32 → TFLite): 29.19%
#   Model size reduction: 78.65%
#   Latency improvement: -83.60%
#
# Comparison saved to: c:\Users\k nithin\Downloads\M.Tech Project\results\quantization\xception_kd_quantization_comparison.csv

# %% [markdown]
# ## Step 7: Visualizations

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

for idx, (cm, title) in enumerate([
    (fp32_metrics['cm'], 'FP32 KD Student'),
    (tflite_metrics['cm'], 'INT8 Quantized')
]):
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[idx],
                xticklabels=class_names, yticklabels=class_names)
    axes[idx].set_title(title)
    axes[idx].set_xlabel('Predicted')
    axes[idx].set_ylabel('True')

plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "xception_kd_quantization_confusion_matrices.png"), dpi=150, bbox_inches='tight')
plt.show()

print(f"Confusion matrices saved")
# Out:
# Confusion matrices saved

# %%
fig, ax = plt.subplots(figsize=(7, 5))

models = ['FP32\nBaseline', 'INT8\nQuantized']
accuracies = [
    fp32_metrics['accuracy'],
    tflite_metrics['accuracy']
]

bars = ax.bar(models, accuracies, color=['#1f77b4', '#2ca02c'], alpha=0.7, edgecolor='black')
ax.set_ylabel('Accuracy', fontsize=12)
ax.set_title('Accuracy Comparison: FP32 vs INT8 Quantized', fontsize=14, fontweight='bold')
ax.set_ylim([min(accuracies) - 0.05, 1.05])
ax.grid(axis='y', alpha=0.3)

for bar, acc in zip(bars, accuracies):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2., height,
            f'{acc:.4f}',
            ha='center', va='bottom', fontsize=11, fontweight='bold')

plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "xception_kd_quantization_accuracy_comparison.png"), dpi=150, bbox_inches='tight')
plt.show()

print(f"Accuracy comparison plot saved")
# Out:
# Accuracy comparison plot saved

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 5))

models = ['FP32\nBaseline', 'INT8\nQuantized']
sizes = [
    fp32_model_size_kb / 1024,
    quantized_model_size_kb / 1024
]
latencies = [
    fp32_metrics['latency_ms'],
    tflite_metrics['latency_ms']
]

bars1 = ax1.bar(models, sizes, color=['#1f77b4', '#2ca02c'], alpha=0.7, edgecolor='black')
ax1.set_ylabel('Model Size (MB)', fontsize=12)
ax1.set_title('Model Size Comparison', fontsize=13, fontweight='bold')
ax1.grid(axis='y', alpha=0.3)

for bar, size in zip(bars1, sizes):
    height = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2., height,
            f'{size:.2f}',
            ha='center', va='bottom', fontsize=10, fontweight='bold')

bars2 = ax2.bar(models, latencies, color=['#1f77b4', '#2ca02c'], alpha=0.7, edgecolor='black')
ax2.set_ylabel('Latency (ms)', fontsize=12)
ax2.set_title('Inference Latency (per image)', fontsize=13, fontweight='bold')
ax2.grid(axis='y', alpha=0.3)

for bar, lat in zip(bars2, latencies):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height,
            f'{lat:.2f}',
            ha='center', va='bottom', fontsize=10, fontweight='bold')

plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, "xception_kd_quantization_size_latency.png"), dpi=150, bbox_inches='tight')
plt.show()

print(f"Size and latency comparison plots saved")
# Out:
# Size and latency comparison plots saved

# %% [markdown]
# ## Summary

# %%
print("\n" + "="*80)
print("QUANTIZATION SUMMARY")
print("="*80)
print(f"\n✓ FP32 baseline loaded and evaluated")
print(f"  - Accuracy: {fp32_metrics['accuracy']:.4f}")
print(f"  - Model size: {fp32_model_size_kb / 1024:.2f} MB")

print(f"\n✓ TFLite quantization completed")
print(f"  - Accuracy: {tflite_metrics['accuracy']:.4f}")
print(f"  - Accuracy drop: {(fp32_metrics['accuracy'] - tflite_metrics['accuracy']) * 100:.2f}%")
print(f"  - Model size: {quantized_model_size_kb / 1024:.2f} MB")
print(f"  - Size reduction: {size_reduction:.2f}%")
print(f"  - Latency improvement: {latency_improvement:.2f}%")

print(f"\n✓ Results saved to: {RESULTS_DIR}")
print(f"  - CSV: xception_kd_quantization_comparison.csv")
print(f"  - Plots: confusion_matrices, accuracy_comparison, size_latency")
print(f"\n✓ Models saved to: {SAVE_DIR}")
print(f"  - xception_beans_distilled_quantized.tflite")
print("\n" + "="*80)
# Out:
# ================================================================================
# QUANTIZATION SUMMARY
# ================================================================================
#
# ✓ FP32 baseline loaded and evaluated
#   - Accuracy: 0.9464
#   - Model size: 98.95 MB
#
# ✓ TFLite quantization completed
#   - Accuracy: 0.6545
#   - Accuracy drop: 29.19%
#   - Model size: 21.13 MB
#   - Size reduction: 78.65%
#   - Latency improvement: -83.60%
#
# ✓ Results saved to: c:\Users\k nithin\Downloads\M.Tech Project\results\quantization
#   - CSV: xception_kd_quantization_comparison.csv
#   - Plots: confusion_matrices, accuracy_comparison, size_latency
#
# ✓ Models saved to: c:\Users\k nithin\Downloads\M.Tech Project\models
#   - xception_beans_distilled_quantized.tflite
#
# ================================================================================

# %% [markdown]
# ## Code
